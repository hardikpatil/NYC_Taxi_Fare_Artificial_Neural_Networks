# %% [markdown]
# ## XGB

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(df.drop('fare_amount', axis=1),
                                                    df['fare_amount'], test_size=0.2, random_state = 42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (386741, 17)
# (96686, 17)
# (386741,)
# (96686,)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading https://files.pythonhosted.org/packages/5e/49/b95c037b717b4ceadc76b6e164603471225c27052d1611d5a2e832757945/xgboost-0.90-py2.py3-none-win_amd64.whl (18.3MB)
# Requirement already satisfied: scipy in c:\users\hardik patil\anaconda3\lib\site-packages (from xgboost) (1.1.0)
# Requirement already satisfied: numpy in c:\users\hardik patil\anaconda3\lib\site-packages (from xgboost) (1.16.3)
# Installing collected packages: xgboost
# Successfully installed xgboost-0.90
# WARNING: You are using pip version 19.1.1, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import xgboost as xgb

# %%
params = {
   
    'max_depth': 7,
    'gamma' :0,
    'eta':.03, 
    'subsample': 1,
    'colsample_bytree': 0.9, 
    'objective':'reg:linear',
    'eval_metric':'rmse',
    'silent': 0
}

# %%
def XGBmodel(X_train,X_test,y_train,y_test,params):
    matrix_train = xgb.DMatrix(X_train,label=y_train)
    matrix_test = xgb.DMatrix(X_test,label=y_test)
    model=xgb.train(params=params,
                    dtrain=matrix_train,num_boost_round=5000, 
                    early_stopping_rounds=10,evals=[(matrix_test,'test')])
    return model

model = XGBmodel(X_train,X_test,y_train,y_test,params)
# Out:
# C:\Users\Hardik Patil\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [16:42:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	test-rmse:13.2834
# Will train until test-rmse hasn't improved in 10 rounds.
# [1]	test-rmse:12.914
# [2]	test-rmse:12.5563
# [3]	test-rmse:12.23
# [4]	test-rmse:11.8948
# [5]	test-rmse:11.5727
# [6]	test-rmse:11.2586
# [7]	test-rmse:10.9734
# [8]	test-rmse:10.679
# [9]	test-rmse:10.3942
# [10]	test-rmse:10.1186
# [11]	test-rmse:9.85242
# [12]	test-rmse:9.59505
# [13]	test-rmse:9.34666
# [14]	test-rmse:9.10646
# [15]	test-rmse:8.87482
# [16]	test-rmse:8.65058
# [17]	test-rmse:8.44776
# [18]	test-rmse:8.23854
# [19]	test-rmse:8.0365
# [20]	test-rmse:7.84146
# [21]	test-rmse:7.65359
# [22]	test-rmse:7.47264
# [23]	test-rmse:7.29769
# [24]	test-rmse:7.12998
# [25]	test-rmse:6.96765
# [26]	test-rmse:6.81228
# [27]	test-rmse:6.66191
# [28]	test-rmse:6.5172
# [29]	test-rmse:6.37776
# [30]	test-rmse:6.24434
# [31]	test-rmse:6.11545
# [32]	test-rmse:5.99102
# [33]	test-rmse:5.87155
# [34]	test-rmse:5.75723
# [35]	test-rmse:5.64718
# [36]	test-rmse:5.54131
# [37]	test-rmse:5.44037
# [38]	test-rmse:5.34333
# [39]	test-rmse:5.25019
# [40]	test-rmse:5.16515
# [41]	test-rmse:5.07913
# [42]	test-rmse:4.99732
# [43]	test-rmse:4.91861
# [44]	test-rmse:4.84356
# [45]	test-rmse:4.77173
# [46]	test-rmse:4.70266
# [47]	test-rmse:4.63998
# [48]	test-rmse:4.57714
# [49]	test-rmse:4.51682
# [50]	test-rmse:4.45907
# [51]	test-rmse:4.40419
# [52]	test-rmse:4.35204
# [53]	test-rmse:4.30215
# [54]	test-rmse:4.2545
# [55]	test-rmse:4.20906
# [56]	test-rmse:4.16746
# [57]	test-rmse:4.12604
# [58]	test-rmse:4.08647
# [59]	test-rmse:4.05044
# [60]	test-rmse:4.01448
# [61]	test-rmse:3.98049
# [62]	test-rmse:3.9479
# [63]	test-rmse:3.91719
# [64]	test-rmse:3.88902
# [65]	test-rmse:3.86113
# [66]	test-rmse:3.83437
# [67]	test-rmse:3.80933
# [68]	test-rmse:3.7854
# [69]	test-rmse:3.76221
# [70]	test-rmse:3.7408
# [71]	test-rmse:3.72073
# [72]	test-rmse:3.70117
# [73]	test-rmse:3.68258
# [74]	test-rmse:3.66503
# [75]	test-rmse:3.64801
# [76]	test-rmse:3.63203
# [77]	test-rmse:3.61696
# [78]	test-rmse:3.60252
# [79]	test-rmse:3.5885
# [80]	test-rmse:3.57568
# [81]	test-rmse:3.56354
# [82]	test-rmse:3.55222
# [83]	test-rmse:3.54063
# [84]	test-rmse:3.52976
# [85]	test-rmse:3.51934
# [86]	test-rmse:3.50928
# [87]	test-rmse:3.49982
# [88]	test-rmse:3.49077
# [89]	test-rmse:3.48169
# [90]	test-rmse:3.4736
# [91]	test-rmse:3.46572
# [92]	test-rmse:3.45815
# [93]	test-rmse:3.45073
# [94]	test-rmse:3.4438
# [95]	test-rmse:3.43684
# [96]	test-rmse:3.43097
# [97]	test-rmse:3.42477
# [98]	test-rmse:3.41935
# [99]	test-rmse:3.41379
# [100]	test-rmse:3.40867
# [101]	test-rmse:3.40422
# [102]	test-rmse:3.39988
# [103]	test-rmse:3.39546
# [104]	test-rmse:3.39064
# [105]	test-rmse:3.38641
# [106]	test-rmse:3.38237
# [107]	test-rmse:3.37847
# [108]	test-rmse:3.37493
# [109]	test-rmse:3.37165
# [110]	test-rmse:3.36873
# [111]	test-rmse:3.36539
# [112]	test-rmse:3.36239
# [113]	test-rmse:3.35965
# [114]	test-rmse:3.35583
# [115]	test-rmse:3.35306
# [116]	test-rmse:3.35009
# [117]	test-rmse:3.34662
# [118]	test-rmse:3.34293
# [119]	test-rmse:3.3402
# [120]	test-rmse:3.33867
# [121]	test-rmse:3.33654
# [122]	test-rmse:3.33426
# [123]	test-rmse:3.33118
# [124]	test-rmse:3.32962
# [125]	test-rmse:3.32678
# [126]	test-rmse:3.32458
# [127]	test-rmse:3.32234
# [128]	test-rmse:3.31932
# [129]	test-rmse:3.31801
# [130]	test-rmse:3.31611
# [131]	test-rmse:3.31482
# [132]	test-rmse:3.31205
# [133]	test-rmse:3.31064
# [134]	test-rmse:3.30956
# [135]	test-rmse:3.30783
# [136]	test-rmse:3.30572
# [137]	test-rmse:3.30443
# [138]	test-rmse:3.30316
# [139]	test-rmse:3.30195
# [140]	test-rmse:3.30039
# [141]	test-rmse:3.29929
# [142]	test-rmse:3.29831
# [143]	test-rmse:3.29749
# [144]	test-rmse:3.29606
# [145]	test-rmse:3.29439
# [146]	test-rmse:3.29348
# [147]	test-rmse:3.29259
# [148]	test-rmse:3.29147
# [149]	test-rmse:3.29088
# [150]	test-rmse:3.28967
# [151]	test-rmse:3.289
# [152]	test-rmse:3.28789
# [153]	test-rmse:3.28691
# [154]	test-rmse:3.28555
# [155]	test-rmse:3.28427
# [156]	test-rmse:3.28346
# [157]	test-rmse:3.28241
# [158]	test-rmse:3.2821
# [159]	test-rmse:3.28129
# [160]	test-rmse:3.28035
# [161]	test-rmse:3.27953
# [162]	test-rmse:3.27886
# [163]	test-rmse:3.27827
# [164]	test-rmse:3.27681
# [165]	test-rmse:3.27604
# [166]	test-rmse:3.27527
# [167]	test-rmse:3.27343
# [168]	test-rmse:3.27264
# [169]	test-rmse:3.27161
# [170]	test-rmse:3.27089
# [171]	test-rmse:3.27022
# [172]	test-rmse:3.26973
# [173]	test-rmse:3.26887
# [174]	test-rmse:3.26803
# [175]	test-rmse:3.26764
# [176]	test-rmse:3.26719
# [177]	test-rmse:3.2669
# [178]	test-rmse:3.26621
# [179]	test-rmse:3.26554
# [180]	test-rmse:3.26522
# [181]	test-rmse:3.26438
# [182]	test-rmse:3.26434
# [183]	test-rmse:3.26419
# [184]	test-rmse:3.26371
# [185]	test-rmse:3.26306
# [186]	test-rmse:3.26255
# [187]	test-rmse:3.26195
# [188]	test-rmse:3.26083
# [189]	test-rmse:3.26016
# [190]	test-rmse:3.26008
# [191]	test-rmse:3.25919
# [192]	test-rmse:3.25827
# [193]	test-rmse:3.25789
# [194]	test-rmse:3.25678
# [195]	test-rmse:3.25621
# [196]	test-rmse:3.25566
# [197]	test-rmse:3.25515
# [198]	test-rmse:3.25474
# [199]	test-rmse:3.25457
# [200]	test-rmse:3.25435
# [201]	test-rmse:3.25345
# [202]	test-rmse:3.25274
# [203]	test-rmse:3.25238
# [204]	test-rmse:3.25202
# [205]	test-rmse:3.25168
# [206]	test-rmse:3.25145
# [207]	test-rmse:3.25116
# [208]	test-rmse:3.25027
# [209]	test-rmse:3.25
# [210]	test-rmse:3.24962
# [211]	test-rmse:3.24892
# [212]	test-rmse:3.2484
# [213]	test-rmse:3.24812
# [214]	test-rmse:3.24774
# [215]	test-rmse:3.24751
# [216]	test-rmse:3.24663
# [217]	test-rmse:3.24589
# [218]	test-rmse:3.24523
# [219]	test-rmse:3.24497
# [220]	test-rmse:3.24493
# [221]	test-rmse:3.24496
# [222]	test-rmse:3.2445
# [223]	test-rmse:3.2442
# [224]	test-rmse:3.24365
# [225]	test-rmse:3.24374
# [226]	test-rmse:3.24315
# [227]	test-rmse:3.24287
# [228]	test-rmse:3.24217
# [229]	test-rmse:3.24134
# [230]	test-rmse:3.24052
# [231]	test-rmse:3.23991
# [232]	test-rmse:3.23931
# [233]	test-rmse:3.23891
# [234]	test-rmse:3.23842
# [235]	test-rmse:3.23835
# [236]	test-rmse:3.23776
# [237]	test-rmse:3.23745
# [238]	test-rmse:3.23754
# [239]	test-rmse:3.23755
# [240]	test-rmse:3.23712
# [241]	test-rmse:3.23702
# [242]	test-rmse:3.23695
# [243]	test-rmse:3.23669
# [244]	test-rmse:3.23658
# [245]	test-rmse:3.23641
# [246]	test-rmse:3.23568
# [247]	test-rmse:3.23574
# [248]	test-rmse:3.23542
# [249]	test-rmse:3.23527
# [250]	test-rmse:3.23445
# [251]	test-rmse:3.23398
# [252]	test-rmse:3.23382
# [253]	test-rmse:3.23311
# [254]	test-rmse:3.23314
# [255]	test-rmse:3.23287
# [256]	test-rmse:3.23255
# [257]	test-rmse:3.23256
# [258]	test-rmse:3.23163
# [259]	test-rmse:3.23125
# [260]	test-rmse:3.23119
# [261]	test-rmse:3.23068
# [262]	test-rmse:3.23049
# [263]	test-rmse:3.23018
# [264]	test-rmse:3.23002
# [265]	test-rmse:3.2299
# [266]	test-rmse:3.22985
# [267]	test-rmse:3.22953
# [268]	test-rmse:3.22941
# [269]	test-rmse:3.22915
# [270]	test-rmse:3.22917
# [271]	test-rmse:3.22851
# [272]	test-rmse:3.22776
# [273]	test-rmse:3.2279
# [274]	test-rmse:3.22797
# [275]	test-rmse:3.22794
# [276]	test-rmse:3.22786
# [277]	test-rmse:3.22731
# [278]	test-rmse:3.22674
# [279]	test-rmse:3.2268
# [280]	test-rmse:3.22609
# [281]	test-rmse:3.22587
# [282]	test-rmse:3.22469
# [283]	test-rmse:3.22461
# [284]	test-rmse:3.22349
# [285]	test-rmse:3.22302
# [286]	test-rmse:3.22308
# [287]	test-rmse:3.22295
# [288]	test-rmse:3.22257
# [289]	test-rmse:3.22251
# [290]	test-rmse:3.2223
# [291]	test-rmse:3.22154
# [292]	test-rmse:3.22131
# [293]	test-rmse:3.22053
# [294]	test-rmse:3.22042
# [295]	test-rmse:3.22047
# [296]	test-rmse:3.22063
# [297]	test-rmse:3.22071
# [298]	test-rmse:3.2199
# [299]	test-rmse:3.21913
# [300]	test-rmse:3.21883
# [301]	test-rmse:3.2188
# [302]	test-rmse:3.2186
# [303]	test-rmse:3.21871
# [304]	test-rmse:3.2182
# [305]	test-rmse:3.21828
# [306]	test-rmse:3.21736
# [307]	test-rmse:3.21718
# [308]	test-rmse:3.21735
# [309]	test-rmse:3.21699
# [310]	test-rmse:3.21577
# [311]	test-rmse:3.21577
# [312]	test-rmse:3.21567
# [313]	test-rmse:3.21563
# [314]	test-rmse:3.21554
# [315]	test-rmse:3.2154
# [316]	test-rmse:3.21536
# [317]	test-rmse:3.21542
# [318]	test-rmse:3.21435
# [319]	test-rmse:3.21407
# [320]	test-rmse:3.21368
# [321]	test-rmse:3.21379
# [322]	test-rmse:3.21293
# [323]	test-rmse:3.21286
# [324]	test-rmse:3.21273
# [325]	test-rmse:3.21282
# [326]	test-rmse:3.2123
# [327]	test-rmse:3.21185
# [328]	test-rmse:3.21176
# [329]	test-rmse:3.21177
# [330]	test-rmse:3.21081
# [331]	test-rmse:3.21073
# [332]	test-rmse:3.21065
# [333]	test-rmse:3.21055
# [334]	test-rmse:3.21007
# [335]	test-rmse:3.20966
# [336]	test-rmse:3.20952
# [337]	test-rmse:3.20948
# [338]	test-rmse:3.20909
# [339]	test-rmse:3.20834
# [340]	test-rmse:3.20833
# [341]	test-rmse:3.20763
# [342]	test-rmse:3.20761
# [343]	test-rmse:3.20771
# [344]	test-rmse:3.20765
# [345]	test-rmse:3.20719
# [346]	test-rmse:3.20693
# [347]	test-rmse:3.20659
# [348]	test-rmse:3.20655
# [349]	test-rmse:3.20649
# [350]	test-rmse:3.20587
# [351]	test-rmse:3.20587
# [352]	test-rmse:3.20573
# [353]	test-rmse:3.20502
# [354]	test-rmse:3.20435
# [355]	test-rmse:3.20433
# [356]	test-rmse:3.20406
# [357]	test-rmse:3.20402
# [358]	test-rmse:3.2039
# [359]	test-rmse:3.20384
# [360]	test-rmse:3.20343
# [361]	test-rmse:3.20355
# [362]	test-rmse:3.20344
# [363]	test-rmse:3.20316
# [364]	test-rmse:3.20311
# [365]	test-rmse:3.20309
# [366]	test-rmse:3.20296
# [367]	test-rmse:3.20298
# [368]	test-rmse:3.20282
# [369]	test-rmse:3.20273
# [370]	test-rmse:3.20226
# [371]	test-rmse:3.20178
# [372]	test-rmse:3.20135
# [373]	test-rmse:3.20113
# [374]	test-rmse:3.20079
# [375]	test-rmse:3.20047
# [376]	test-rmse:3.20033
# [377]	test-rmse:3.19952
# [378]	test-rmse:3.19955
# [379]	test-rmse:3.1993
# [380]	test-rmse:3.19913
# [381]	test-rmse:3.19944
# [382]	test-rmse:3.19929
# [383]	test-rmse:3.19925
# [384]	test-rmse:3.19924
# [385]	test-rmse:3.19917
# [386]	test-rmse:3.19912
# [387]	test-rmse:3.19895
# [388]	test-rmse:3.19921
# [389]	test-rmse:3.19907
# [390]	test-rmse:3.19897
# [391]	test-rmse:3.19898
# [392]	test-rmse:3.19856
# [393]	test-rmse:3.19825
# [394]	test-rmse:3.19814
# [395]	test-rmse:3.19798
# [396]	test-rmse:3.19785
# [397]	test-rmse:3.19779
# [398]	test-rmse:3.19779
# [399]	test-rmse:3.19781
# [400]	test-rmse:3.19767
# [401]	test-rmse:3.19753
# [402]	test-rmse:3.19708
# [403]	test-rmse:3.1971
# [404]	test-rmse:3.19705
# [405]	test-rmse:3.19686
# [406]	test-rmse:3.19676
# [407]	test-rmse:3.19682
# [408]	test-rmse:3.19672
# [409]	test-rmse:3.19646
# [410]	test-rmse:3.19633
# [411]	test-rmse:3.19643
# [412]	test-rmse:3.19623
# [413]	test-rmse:3.19606
# [414]	test-rmse:3.19606
# [415]	test-rmse:3.19595
# [416]	test-rmse:3.19585
# [417]	test-rmse:3.19568
# [418]	test-rmse:3.1957
# [419]	test-rmse:3.19567
# [420]	test-rmse:3.19551
# [421]	test-rmse:3.19542
# [422]	test-rmse:3.1953
# [423]	test-rmse:3.19518
# [424]	test-rmse:3.19456
# [425]	test-rmse:3.19494
# [426]	test-rmse:3.19486
# [427]	test-rmse:3.19465
# [428]	test-rmse:3.19457
# [429]	test-rmse:3.19445
# [430]	test-rmse:3.19422
# [431]	test-rmse:3.19407
# [432]	test-rmse:3.19398
# [433]	test-rmse:3.1939
# [434]	test-rmse:3.19368
# [435]	test-rmse:3.19367
# [436]	test-rmse:3.19378
# [437]	test-rmse:3.19363
# [438]	test-rmse:3.19344
# [439]	test-rmse:3.19327
# [440]	test-rmse:3.19311
# [441]	test-rmse:3.193
# [442]	test-rmse:3.19328
# [443]	test-rmse:3.19286
# [444]	test-rmse:3.19271
# [445]	test-rmse:3.19259
# [446]	test-rmse:3.19252
# [447]	test-rmse:3.19258
# [448]	test-rmse:3.19261
# [449]	test-rmse:3.19245
# [450]	test-rmse:3.1921
# [451]	test-rmse:3.19218
# [452]	test-rmse:3.19216
# [453]	test-rmse:3.19159
# [454]	test-rmse:3.19145
# [455]	test-rmse:3.19134
# [456]	test-rmse:3.19102
# [457]	test-rmse:3.19086
# [458]	test-rmse:3.19087
# [459]	test-rmse:3.19083
# [460]	test-rmse:3.19076
# [461]	test-rmse:3.19022
# [462]	test-rmse:3.18969
# [463]	test-rmse:3.18962
# [464]	test-rmse:3.18942
# [465]	test-rmse:3.18938
# [466]	test-rmse:3.18938
# [467]	test-rmse:3.18939
# [468]	test-rmse:3.18932
# [469]	test-rmse:3.18928
# [470]	test-rmse:3.18929
# [471]	test-rmse:3.18873
# [472]	test-rmse:3.18859
# [473]	test-rmse:3.18848
# [474]	test-rmse:3.18846
# [475]	test-rmse:3.18852
# [476]	test-rmse:3.18852
# [477]	test-rmse:3.18788
# [478]	test-rmse:3.18784
# [479]	test-rmse:3.18736
# [480]	test-rmse:3.18704
# [481]	test-rmse:3.18718
# [482]	test-rmse:3.18699
# [483]	test-rmse:3.18684
# [484]	test-rmse:3.18685
# [485]	test-rmse:3.18678
# [486]	test-rmse:3.18677
# [487]	test-rmse:3.18672
# [488]	test-rmse:3.1868
# [489]	test-rmse:3.18657
# [490]	test-rmse:3.18638
# [491]	test-rmse:3.18607
# [492]	test-rmse:3.18589
# [493]	test-rmse:3.18548
# [494]	test-rmse:3.1854
# [495]	test-rmse:3.18546
# [496]	test-rmse:3.18542
# [497]	test-rmse:3.18538
# [498]	test-rmse:3.1854
# [499]	test-rmse:3.18514
# [500]	test-rmse:3.18514
# [501]	test-rmse:3.18518
# [502]	test-rmse:3.18513
# [503]	test-rmse:3.18513
# [504]	test-rmse:3.18517
# [505]	test-rmse:3.1849
# [506]	test-rmse:3.18489
# [507]	test-rmse:3.1847
# [508]	test-rmse:3.18447
# [509]	test-rmse:3.18445
# [510]	test-rmse:3.18394
# [511]	test-rmse:3.1839
# [512]	test-rmse:3.18379
# [513]	test-rmse:3.18369
# [514]	test-rmse:3.18353
# [515]	test-rmse:3.18354
# [516]	test-rmse:3.18354
# [517]	test-rmse:3.18359
# [518]	test-rmse:3.18359
# [519]	test-rmse:3.18359
# [520]	test-rmse:3.18337
# [521]	test-rmse:3.18331
# [522]	test-rmse:3.1834
# [523]	test-rmse:3.18335
# [524]	test-rmse:3.18319
# [525]	test-rmse:3.18301
# [526]	test-rmse:3.18287
# [527]	test-rmse:3.18285
# [528]	test-rmse:3.18279
# [529]	test-rmse:3.18241
# [530]	test-rmse:3.18182
# [531]	test-rmse:3.18177
# [532]	test-rmse:3.18176
# [533]	test-rmse:3.18179
# [534]	test-rmse:3.18174
# [535]	test-rmse:3.18171
# [536]	test-rmse:3.18112
# [537]	test-rmse:3.181
# [538]	test-rmse:3.18103
# [539]	test-rmse:3.18098
# [540]	test-rmse:3.18086
# [541]	test-rmse:3.18076
# [542]	test-rmse:3.18078
# [543]	test-rmse:3.18066
# [544]	test-rmse:3.18057
# [545]	test-rmse:3.18058
# [546]	test-rmse:3.18062
# [547]	test-rmse:3.18071
# [548]	test-rmse:3.18065
# [549]	test-rmse:3.18064
# [550]	test-rmse:3.18038
# [551]	test-rmse:3.18033
# [552]	test-rmse:3.18041
# [553]	test-rmse:3.18039
# [554]	test-rmse:3.18039
# [555]	test-rmse:3.17999
# [556]	test-rmse:3.17976
# [557]	test-rmse:3.17962
# [558]	test-rmse:3.17956
# [559]	test-rmse:3.17956
# [560]	test-rmse:3.17956
# [561]	test-rmse:3.17933
# [562]	test-rmse:3.17909
# [563]	test-rmse:3.17909
# [564]	test-rmse:3.17892
# [565]	test-rmse:3.17895
# [566]	test-rmse:3.1789
# [567]	test-rmse:3.17883
# [568]	test-rmse:3.17878
# [569]	test-rmse:3.17879
# [570]	test-rmse:3.17876
# [571]	test-rmse:3.1788
# [572]	test-rmse:3.17865
# [573]	test-rmse:3.17866
# [574]	test-rmse:3.17853
# [575]	test-rmse:3.17842
# [576]	test-rmse:3.17829
# [577]	test-rmse:3.17823
# [578]	test-rmse:3.17829
# [579]	test-rmse:3.17849
# [580]	test-rmse:3.17862
# [581]	test-rmse:3.17859
# [582]	test-rmse:3.17867
# [583]	test-rmse:3.17849
# [584]	test-rmse:3.17853
# [585]	test-rmse:3.17859
# [586]	test-rmse:3.17828
# [587]	test-rmse:3.17827
# Stopping. Best iteration:
# [577]	test-rmse:3.17823

# %% [markdown]
# ## Simple Linear Regression

# %%
df['abs_diff_longitude'] = (df.dropoff_longitude - df.pickup_longitude).abs()
df['abs_diff_latitude'] = (df.dropoff_latitude - df.pickup_latitude).abs()

def get_input_matrix(df):
    return np.column_stack((df.abs_diff_longitude, df.abs_diff_latitude, np.ones(len(df))))

train_X = get_input_matrix(df)
train_y = np.array(df['fare_amount'])

print(train_X.shape)
print(train_y.shape)
# Out:
# (483427, 3)
# (483427,)

# %%
import numpy as np
(w, _, _, _) = np.linalg.lstsq(train_X, train_y, rcond = None)
print(w)
# Out:
# [5.69981963 3.86640559 4.28310581]

# %%
w_OLS = np.matmul(np.matmul(np.linalg.inv(np.matmul(train_X.T, train_X)), train_X.T), train_y)
print(w_OLS)
# Out:
# [5.69981963 3.86640559 4.28310581]
